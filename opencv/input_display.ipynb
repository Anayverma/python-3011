# %%
import cv2

# %%
# input and display the image 
import cv2
# read an image 
# img = cv2.imread("C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png",0-greyscale 1-color/original)


img = cv2.imread("C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png",1)

# signal to digital conversion 
# imageg to numbers -- 0s ands 1s for grayscale and 0-255 in color
# display the image
cv2.imshow("image", img)

# retend the image in screen 
cv2.waitKey(100000)

# terminate the window
cv2.destroyAllWindows()

# %%
# input and display the image in GRAYSCALE
import cv2
# read an image 
# img = cv2.imread("C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png",0-greyscale 1-color/original)


img = cv2.imread("C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png",0)

# signal to digital conversion 
# imageg to numbers -- 0s ands 1s for grayscale and 0-255 in color
# display the image
cv2.imshow("image", img)

# retend the image in screen 
cv2.waitKey(1000)

# terminate the window
cv2.destroyAllWindows()

# %%
# rotate by 150 degree
import cv2
import numpy as np

# Load the image
img = cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png')  # Replace 'your_image_path.jpg' with the actual path of your image

print(img.shape[:])
# Get the height and width of the image
height, width = img.shape[:2]

# Define the rotation angle (150 degrees)
angle = 150

# Calculate the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1)

# Apply the rotation to the image
rotated_image = cv2.warpAffine(img, rotation_matrix, (width, height))

# Display the original and rotated images (optional)
cv2.imshow('Original Image', img)
cv2.imshow('Rotated Image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (616, 1070, 3)

# %%
# resize to 200 x 200
import cv2
import numpy as np

# Load the image
img = cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png')  # Replace with the actual path of your image

# Resize the original image to 200x200
resized_image = cv2.resize(img, (200, 200))

# Display the original and resized images
cv2.imshow('Original Image', img)
cv2.imshow('Resized Image', resized_image)

# Wait for a key event and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# to flip an image 
import cv2

img=cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png')

flipped_img = cv2.flip(img, 1)
flipped_img_vert = cv2.flip(img, 0)

cv2.imshow("Original image  ",img)
cv2.imshow("Flipped image -HORIZONTALLY ",flipped_img)
cv2.imshow("Flipped image -VERTICALLY ",flipped_img_vert)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#  to change the contrast of image  
import cv2
img= cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png',1)
cv2.imshow("Original image  ",img)

alpha= 1.5
beta=30
 
altered_img=cv2.convertScaleAbs(img,alpha=alpha,beta=beta)
cv2.imshow("ALtered image with alpha changed to {} and beta changed to {}".format(alpha,beta),altered_img)
# combined_img=cv2.hconcat([img,altered_img])
# cv2.imshow("Results are --",combined_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# to change the brightness of image 
import cv2


img= cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png',1)
cv2.imshow("original image --",img)

alter =1
beta=50

brighted_img=cv2.convertScaleAbs(img,alpha=alpha,beta=beta)
cv2.imshow("brightened image --",brighted_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
img= cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png',1)


height, width = img.shape[:2]
cv2.imshow("original img -- {} x{}".format(height,width),img)
# xs,xe,ys,ye=map(int,input().split())
xs,xe,ys,ye=100,200,100,400


cropped_img=img[xs:xe,ys:ye]
cv2.imshow("cropped image --",cropped_img)

# print(img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# threshold an image
import cv2
img= cv2.imread('C:\\Users\\Ananya Verma\\Desktop\\python 3011\\opencv\\image.png',0)
cv2.imshow("original img --",img)

threshold_value = 20  
_,thresholded_img = cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)
cv2.imshow("threshold  img --",thresholded_img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# background Substraction of image

import cv2
import numpy as np

# Read the input image
image = cv2.imread('img.jpeg')  # Replace 'your_image_file.jpg' with the path to your image file

# Create a background subtractor object using MOG2
fgbg = cv2.createBackgroundSubtractorMOG2()

# Apply the background subtractor to the image
fgmask = fgbg.apply(image)

# Optionally, you can perform additional processing on the foreground mask
# For example, you can use thresholding to create a binary mask
_, binary_mask = cv2.threshold(fgmask, 127, 255, cv2.THRESH_BINARY)

# Display the original image and the foreground mask
cv2.imshow('Original Image', image)
cv2.imshow('Foreground Mask', fgmask)
cv2.imshow('Binary Mask', binary_mask)

# Wait for a key press and then close all windows
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# edge detection of image
import cv2
import numpy as np

# Read the input image
image = cv2.imread('img.jpg')  # Replace 'your_image_file.jpg' with the path to your image file

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise and improve edge detection
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply the Canny edge detector
edges = cv2.Canny(blurred, 50, 150)

# Display the original image and the detected edges
cv2.imshow('Original Image', image)
cv2.imshow('Edges', edges)

# Wait for a key press and then close all windows
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# edge detction using sobbkl opertor
import cv2
import numpy as np

def sobel_edge_detection(image_path):
    # Step 1: Read the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Step 2: Apply Sobel operator for edge detection
    sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

    # Step 3: Combine the gradients to obtain the magnitude
    magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
    magnitude = np.uint8(magnitude)

    # Display the original image and the result
    cv2.imshow('Original Image', image)
    cv2.imshow('Sobel Edge Detection', magnitude)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage
image_path = 'img.jpg'
sobel_edge_detection(image_path)
